# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 2000
sig1 = np.sin(np.linspace(0,6*np.pi,n))
sig2 = np.random.rand(n)*2-1

combi = sig1 + sig2

fix, ax = plt.subplots(2,3,figsize=(10,4))

ax[0,0].plot(sig1)
ax[0,0].set_title('Sine wave')
ax[1,0].hist(sig1,100)

ax[0,1].plot(sig2, '.', alpha =.3)
ax[0,1].set_title('Uniform numbers')
ax[1,1].hist(sig2,100)

ax[0,2].plot(combi, '.', alpha =.3)
ax[0,2].set_title('Combinated signal')
ax[1,2].hist(combi,100)

# ax is a matrix so if we want to loop through it we have apply vectorization to it

print(np.shape(np.matrix.flatten(ax)))

for i in np.matrix.flatten(ax):
    i.set_xticks([])
    i.set_yticks([])

plt.show()
# Out:
# (6,)

# %%
import seaborn as sns

sns.set()

sns.displot(combi, kde=True, bins=100)

plt.show()

# %%
ns = np.arange(50,10000,100)
nbins = 50

allhist = np.zeros((len(ns), nbins))

for i in range(len(ns)):
    sig1 = np.sin(np.linspace(0,6*np.pi,ns[i]))
    sig2 = (np.random.rand(ns[i])*2-1 )
    
    allhist[i,:],x = np.histogram(sig1+sig2,nbins, density=True)
    
plt.pcolor(x[:-1], ns, allhist, vmax=.6, cmap='Purples')
plt.xlabel('Data Value')
plt.ylabel('Points in the sample')
plt.colorbar()
plt.show()
# Out:
# C:\Users\DANNY\AppData\Local\Temp\ipykernel_1140\780043223.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolor(x[:-1], ns, allhist, vmax=.6, cmap='Purples')
# C:\Users\DANNY\AppData\Local\Temp\ipykernel_1140\780043223.py:15: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
