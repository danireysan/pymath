# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 500
x = .5+np.zeros(N)
rs =np.linspace(1,4,1000)
endcap = np.arange(round(N*.9), N )
for ri in range(len(rs)):
    
    for n in range(N-1):
        x[n+1] = rs[ri]*x[n]*(1-x[n])
    
    u = np.unique(x[endcap])
    r =rs[ri]*np.ones(len(u))
    crazyRGB = [(np.sin(ri/len(rs)/2)+1)/2, 1-ri/len(rs),.7]
    plt.plot(r,u, '.', markersize=1, color = crazyRGB )
 
plt.show()

# %%
N = 500
x = .5+np.zeros(N)
rs =np.linspace(1,4,1000)
endcap = np.arange(round(N*.9), N )
for ri in range(len(rs)):
    
    for n in range(N-1):
        x[n+1] = rs[ri]*x[n]*(1-x[n])
    
    u = np.unique(x[endcap])
    r =rs[ri]*np.ones(len(u))
    crazyRGB = [1-ri/len(rs),.7, (np.sin(ri/len(rs)/2)+1)/2]
    plt.plot(r,u, '.', markersize=1, color = crazyRGB )
 
plt.show()

# %%
N = 500
x = .5+np.zeros(N)
rs =np.linspace(1,4,1000)
endcap = np.arange(round(N*.9), N )
for ri in range(len(rs)):
    
    for n in range(N-1):
        x[n+1] = rs[ri]*x[n]*(1-x[n])
    
    u = np.unique(x[endcap])
    r =rs[ri]*np.ones(len(u))
    crazyRGB = [.5, 1-ri/len(rs),(np.sin(ri/len(rs)/2)+1)/2]
    plt.plot(r,u, '.', markersize=1, color = crazyRGB )
 
plt.show()

# %%
N = 500
x = .5+np.zeros(N)
rs =np.linspace(1,4,1000)
endcap = np.arange(round(N*.9), N )
for ri in range(len(rs)):
    
    for n in range(N-1):
        x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2
    
    u = np.unique(x[endcap])
    r =rs[ri]*np.ones(len(u))
    crazyRGB = [(np.sin(ri/len(rs)/2)+1)/2, 1-ri/len(rs),.7]
    plt.plot(r,u, '.', markersize=1, color = crazyRGB )
 
plt.show()
# Out:
# /var/folders/cn/n2jb84q965s2rnkvyvqphf6c0000gn/T/ipykernel_3177/3482427180.py:8: RuntimeWarning: overflow encountered in double_scalars
#   x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2
# /var/folders/cn/n2jb84q965s2rnkvyvqphf6c0000gn/T/ipykernel_3177/3482427180.py:8: RuntimeWarning: invalid value encountered in sin
#   x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2

# %%
N = 500
x = .5+np.zeros(N)
rs =np.linspace(1,4,1000)
endcap = np.arange(round(N*.9), N )
for ri in range(len(rs)):
    
    for n in range(N-1):
        x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2
    
    u = np.unique(x[endcap])
    r =rs[ri]*np.ones(len(u))
    crazyRGB = [ 0.5, (np.sin(ri/len(rs)/2)+1)/2, 1-ri/len(rs)]
    plt.plot(r,u, '.', markersize=1, color = crazyRGB )
 
plt.show()
# Out:
# /var/folders/cn/n2jb84q965s2rnkvyvqphf6c0000gn/T/ipykernel_3177/988200825.py:8: RuntimeWarning: overflow encountered in double_scalars
#   x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2
# /var/folders/cn/n2jb84q965s2rnkvyvqphf6c0000gn/T/ipykernel_3177/988200825.py:8: RuntimeWarning: invalid value encountered in sin
#   x[n+1] = rs[ri]*x[n]*(1-x[n]) + .2*np.sin(2*np.pi*x[n])**2
