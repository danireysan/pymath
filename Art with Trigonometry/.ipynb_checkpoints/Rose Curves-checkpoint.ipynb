# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k = 2.2

t = np.linspace(0,8 * np.pi, 1000 )

x = np.cos(k*t) * np.cos(t)
y = np.cos(k*t) * np.sin(t)

plt.plot(x,y,'m', linewidth=3)
plt.axis('square')
plt.axis('off')

plt.show()

# %%
def clawso (number):
    k = number

    t = np.linspace(0,8 * np.pi, 1000 )

    x = np.cos(k*t) * np.cos(t)
    y = np.cos(k*t) * np.sin(t)

    plt.plot(x,y,'m', linewidth=3)
    plt.axis('square')
    plt.axis('off')

    plt.show()
    
for n in np.arange(0, 4, 0.5):
    clawso(n)

# %%
fig, ax = plt.subplots(3,3, figsize=(10,6))
row, col = np.indices((3,3))

for i in range(0,9):
    k = i/2
    
    x = np.cos(k*t) * np.cos(t)
    y = np.cos(k*t) * np.sin(t)
    
    ax[r,c].plot(x,y, 'm',linewidth=3)
    plt.axis('square')
    plt.axis('off')
    
plt.show()
